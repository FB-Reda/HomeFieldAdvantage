# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('~/Documents/datamining/project/census-data0/ACS_16_5YR_S1903.csv', encoding="latin-1", skiprows=1)
df
# Out:
#                  Id    Id2                                          Geography  \
# 0    310M300US10180  10180                             Abilene, TX Metro Area
# 1    310M300US10380  10380                   Aguadilla-Isabela, PR Metro Area
# 2    310M300US10420  10420                               Akron, OH Metro Area
# 3    310M300US10500  10500                              Albany, GA Metro Area
# 4    310M300US10540  10540                              Albany, OR Metro Area
# 5    310M300US10580  10580             Albany-Schenectady-Troy, NY Metro Area
# 6    310M300US10740  10740                         Albuquerque, NM Metro Area
# 7    310M300US10780  10780                          Alexandria, LA Metro Area
# 8    310M300US10900  10900       Allentown-Bethlehem-Easton, PA-NJ Metro Area
# 9    310M300US11020  11020                             Altoona, PA Metro Area
# 10   310M300US11100  11100                            Amarillo, TX Metro Area
# ...

# %%
arr = {"Boston", "Philadelphia", "Chicago", "Cleveland-", "Detroit", "Indianapolis", "Milwaukee", "Atlanta", "Charlotte-", "Miami", "Orlando", "Washington", "Denver", "Minneapolis", "Oklahoma", "Portland-Vancouver", "Salt Lake", "Oakland", "Phoenix", "Sacramento", "Dallas", "Houston", "Memphis", "New Orleans", "San Antonio"}
df1 = df[["Geography", "Total; Estimate; Households", "Median income (dollars); Estimate; Households"]]
df1
# Out:
#                                              Geography  \
# 0                               Abilene, TX Metro Area
# 1                     Aguadilla-Isabela, PR Metro Area
# 2                                 Akron, OH Metro Area
# 3                                Albany, GA Metro Area
# 4                                Albany, OR Metro Area
# 5               Albany-Schenectady-Troy, NY Metro Area
# 6                           Albuquerque, NM Metro Area
# 7                            Alexandria, LA Metro Area
# 8         Allentown-Bethlehem-Easton, PA-NJ Metro Area
# 9                               Altoona, PA Metro Area
# 10                             Amarillo, TX Metro Area
# 11                                 Ames, IA Metro Area
# 12                            Anchorage, AK Metro Area
# 13                            Ann Arbor, MI Metro Area
# 14         Anniston-Oxford-Jacksonville, AL Metro Area
# 15                             Appleton, WI Metro Area
# ...

# %%
#alternate method of parsing the data, not working

#for column in df1:
#    temp = (df1['Geography'])
#    print(temp)
#    for city in arr:
#        print(city)
#        if city in temp:
#            print(df1.loc[column])
#            df2.append(df1.loc[column])
#
#df1[5]
#df2

# %%
df2 = pd.DataFrame(index=range(3))
cities = pd.DataFrame(index=range(3))
cntr = 1

for city in arr:
    if cntr is 1:
        cities = df1[df1['Geography'].str.contains(city)]
        cntr = cntr + 1
    else:
        df2 = df1[df1['Geography'].str.contains(city)]
        cities = cities.append(df2)

cities = cities.sort_values('Geography', ascending = True)
cities
# Out:
#                                              Geography  \
# 19        Atlanta-Sandy Springs-Roswell, GA Metro Area
# 44           Boston-Cambridge-Newton, MA-NH Metro Area
# 66        Charlotte-Concord-Gastonia, NC-SC Metro Area
# 70       Chicago-Naperville-Elgin, IL-IN-WI Metro Area
# 75                     Cleveland-Elyria, OH Metro Area
# 88          Dallas-Fort Worth-Arlington, TX Metro Area
# 97               Denver-Aurora-Lakewood, CO Metro Area
# 99              Detroit-Warren-Dearborn, MI Metro Area
# 162    Houston-The Woodlands-Sugar Land, TX Metro Area
# 166        Indianapolis-Carmel-Anderson, IN Metro Area
# 227                       Memphis, TN-MS-AR Metro Area
# 229  Miami-Fort Lauderdale-West Palm Beach, FL Metr...
# 233       Milwaukee-Waukesha-West Allis, WI Metro Area
# 234  Minneapolis-St. Paul-Bloomington, MN-WI Metro ...
# 252                New Orleans-Metairie, LA Metro Area
# 261                       Oklahoma City, OK Metro Area
# ...

# %%
nba = pd.read_csv('~/Documents/datamining/project/datasets/NBA.csv', encoding="latin-1")
nba
# Out:
#       Year                 Team  Wins  Loss  Home Wins  Home Loss  Away Wins  \
# 0     1968        Atlanta Hawks    48    34         28         12         18
# 1     1969        Atlanta Hawks    48    34         25         13         18
# 2     1970        Atlanta Hawks    36    46         21         20         14
# 3     1971        Atlanta Hawks    36    46         22         19         13
# 4     1972        Atlanta Hawks    46    36         28         13         17
# 5     1973        Atlanta Hawks    35    47         23         18         12
# 6     1974        Atlanta Hawks    31    51         22         19          9
# 7     1975        Atlanta Hawks    29    53         20         21          9
# 8     1976        Atlanta Hawks    31    51         19         22         12
# 9     1977        Atlanta Hawks    41    41         29         12         12
# 10    1978        Atlanta Hawks    46    36         34          7         12
# ...

# %%
for index, row in nba.iterrows():
    if row["Year"] is 2010:
        print("correct year")

# %%
blank = True
blacklist = {'LosAngeles', 'Los Angeles', 'NewYork', 'New Jersey', 'NewJersey', 'New York', 'Toronto'}

for index, row in nba.iterrows():
    if row["Year"] == 2010:
        blacklisted = False
        for name in blacklist:
            if name in row['Team']:
                blacklisted = True
        if not blacklisted:
            if blank is True:
                combined = pd.DataFrame([[row['Team'],row['HomePCT'],row['TotalPCT'], row['HomePCT']-row['TotalPCT'], 0, 0]], columns = ['Team', 'HomePCT', 'TotalPCT', 'DifferentialPCT', 'MedianIncome', 'TotalHouseholds'])
                blank = False
            else:
                new = pd.DataFrame([[row['Team'],row['HomePCT'],row['TotalPCT'], row['HomePCT']-row['TotalPCT'], 0, 0]], columns = ['Team', 'HomePCT', 'TotalPCT', 'DifferentialPCT', 'MedianIncome', 'TotalHouseholds'])
                combined = combined.append(new)
        
combined
# Out:
#                      Team   HomePCT  TotalPCT  DifferentialPCT  MedianIncome  \
# 0           Atlanta Hawks  0.585366  0.536585         0.048780             0
# 0          Boston Celtics  0.804878  0.682927         0.121951             0
# 0       Charlotte Bobcats  0.512195  0.414634         0.097561             0
# 0           Chicago Bulls  0.878049  0.756098         0.121951             0
# 0     Cleveland Cavaliers  0.292683  0.231707         0.060976             0
# 0        Dallas Mavericks  0.707317  0.695122         0.012195             0
# 0          Denver Nuggets  0.804878  0.609756         0.195122             0
# 0         Detroit Pistons  0.512195  0.365854         0.146341             0
# 0    GoldenState Warriors  0.634146  0.439024         0.195122             0
# 0         Houston Rockets  0.609756  0.524390         0.085366             0
# 0          Indiana Pacers  0.585366  0.451220         0.134146             0
# ...

# %%
metrodict = {'GoldenState' : 'Oakland', 'Minnesota' : 'Minneapolis', 'NewOrleans' : 'New Orleans', 'OklahomaCity' : 'Oklahoma', 'SanAntonio' : 'San Antonio', 'Utah' : 'Salt Lake'}
inclist = [0]
inclist.clear()
houselist = [0]
houselist.clear()

for index, row in combined.iterrows():
    teamplace = row['Team']
    firstword = teamplace.split('\xa0')[0]
    if firstword in metrodict:
        teamplace = metrodict[firstword]
    else:
        teamplace = firstword
    print(teamplace)
    for citindex, citrow in cities.iterrows():
        if teamplace in citrow['Geography']:
            print(citrow['Median income (dollars); Estimate; Households'])
            inclist.append(citrow['Median income (dollars); Estimate; Households'])
            houselist.append(citrow['Total; Estimate; Households'])
    print()
            
len(inclist)
len(combined['MedianIncome'])

combined['MedianIncome'] = inclist
combined['TotalHouseholds'] = houselist
# Out:
# Atlanta
# 59183
#
# Boston
# 77809
#
# Charlotte
# 55191
#
# Chicago
# 63327
#
# Cleveland
# 51001
#
# Dallas
# 61330
#
# Denver
# 68173
#
# Detroit
# 54037
#
# Oakland
# 85947
#
# Houston
# 60902
#
# Indiana
# 54261
#
# Memphis
# 48545
#
# Miami
# 50064
#
# Milwaukee
# 55625
#
# Minneapolis
# 70915
#
# New Orleans
# 48319
#
# Oklahoma
# 52825
#
# Orlando
# 50183
#
# Philadelphia
# 63952
#
# Phoenix
# 55227
#
# Portland
# 62772
#
# Sacramento
# 61686
#
# San Antonio
# 54638
#
# Salt Lake
# 64564
#
# Washington
# 93804

# %%
combined
# Out:
#                      Team   HomePCT  TotalPCT  DifferentialPCT  MedianIncome  \
# 0           Atlanta Hawks  0.585366  0.536585         0.048780         59183
# 0          Boston Celtics  0.804878  0.682927         0.121951         77809
# 0       Charlotte Bobcats  0.512195  0.414634         0.097561         55191
# 0           Chicago Bulls  0.878049  0.756098         0.121951         63327
# 0     Cleveland Cavaliers  0.292683  0.231707         0.060976         51001
# 0        Dallas Mavericks  0.707317  0.695122         0.012195         61330
# 0          Denver Nuggets  0.804878  0.609756         0.195122         68173
# 0         Detroit Pistons  0.512195  0.365854         0.146341         54037
# 0    GoldenState Warriors  0.634146  0.439024         0.195122         85947
# 0         Houston Rockets  0.609756  0.524390         0.085366         60902
# 0          Indiana Pacers  0.585366  0.451220         0.134146         54261
# ...

# %%
combined.plot(kind='scatter', y='DifferentialPCT', x='MedianIncome', s=30)

# %%
regression0 = np.polyfit(combined['MedianIncome'], combined['DifferentialPCT'], 1)
print(regression0)
# Out:
# [  2.18460786e-06  -3.02713336e-02]

# %%
import statsmodels.formula.api as smf

# create a fitted model in one line
lm = smf.ols(formula='DifferentialPCT ~ MedianIncome', data=combined).fit()

# print the coefficients
lm.params
# Out:
# Intercept      -0.030271
# MedianIncome    0.000002
# dtype: float64

# %%
-0.030271 + 0.000002*100000
# Out:
# 0.169729

# %%
52654.547161 + 80801.603400*.05
# Out:
# 56694.627331

# %%
X_0 = pd.DataFrame({'MedianIncome' : [combined.MedianIncome.min(), combined.MedianIncome.max()]})
X_0
# Out:
#    MedianIncome
# 0         48319
# 1         93804

# %%
preds0 = lm.predict(X_0)
preds0
# Out:
# 0    0.075287
# 1    0.174654
# dtype: float64

# %%
combined.plot(kind='scatter', x='MedianIncome', y='DifferentialPCT', title="Median Income vs. DifferentialPCT")
plt.plot(X_0, preds0, c='red', linewidth=2)

# %%
lm.conf_int()
# Out:
#                          0         1
# Intercept    -1.564279e-01  0.095885
# MedianIncome  1.493097e-07  0.000004

# %%
lm.rsquared
# Out:
# 0.17651981800070704

# %%
combined.plot(kind='scatter', y='DifferentialPCT', x='TotalHouseholds', s=30)

# %%
regression1 = np.polyfit(combined['TotalHouseholds'], combined['DifferentialPCT'], 1)
print(regression1)
# Out:
# [  2.50115617e-09   9.95268208e-02]

# %%
import statsmodels.formula.api as smf

# create a fitted model in one line
lm1 = smf.ols(formula='DifferentialPCT ~ TotalHouseholds', data=combined).fit()

# print the coefficients
lm1.params
# Out:
# Intercept          9.952682e-02
# TotalHouseholds    2.501156e-09
# dtype: float64

# %%
X_1 = pd.DataFrame({'TotalHouseholds' : [combined.TotalHouseholds.min(), combined.TotalHouseholds.max()]})
X_1
# Out:
#    TotalHouseholds
# 0           375127
# 1          3464942

# %%
preds1 = lm1.predict(X_1)
preds1
# Out:
# 0    0.100465
# 1    0.108193
# dtype: float64

# %%
combined.plot(kind='scatter', x='TotalHouseholds', y='DifferentialPCT', title="Total Households vs. DifferentialPCT")
plt.plot(X_1, preds1, c='red', linewidth=2)

# %%
lm1.conf_int()
# Out:
#                             0             1
# Intercept        4.895080e-02  1.501028e-01
# TotalHouseholds -2.983310e-08  3.483541e-08

# %%
lm1.rsquared
# Out:
# 0.0011120441364408373
