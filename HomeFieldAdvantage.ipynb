# %%
import pandas as pd

#Set Up Dataframe of Census Data desired, but with all cities
#dfc = Dataframe of all Census Cities
dfc = pd.read_csv("~/GitHub/HomeFieldAdvantage/datasets/census-data/ACS_16_5YR_S1903.csv", encoding='latin-1', index_col=[1], header = 1)


dfc = dfc[['Geography',
           'Total; Estimate; Households','Total; Margin of Error; Households', 
           'Median income (dollars); Estimate; Households', 'Median income (dollars); Margin of Error; Households',
           'Total; Estimate; FAMILIES - Families', 'Total; Margin of Error; FAMILIES - Families', 
           'Median income (dollars); Estimate; FAMILIES - Families', 'Median income (dollars); Margin of Error; FAMILIES - Families',
           'Total; Estimate; NONFAMILY HOUSEHOLDS - Nonfamily households', 'Total; Margin of Error; NONFAMILY HOUSEHOLDS - Nonfamily households', 
           'Median income (dollars); Estimate; NONFAMILY HOUSEHOLDS - Nonfamily households', 'Median income (dollars); Margin of Error; NONFAMILY HOUSEHOLDS - Nonfamily households']]

#Pare it down to desired Cities
#dfc2 = Dataframe of NBA cities
cityArr = {"Atlanta", "Boston", "Charlotte-", "Chicago", "Cleveland-", 
           "Dallas", "Denver", "Detroit", "Houston", "Indianapolis", 
           "Los Angeles", "Memphis", "Miami", "Milwaukee", "Minneapolis", 
           "New Orleans", "New York", "Oakland", "Oklahoma", "Orlando", 
           "Philadelphia", "Phoenix", "Portland-V", "Sacramento",  
           "Salt Lake", "San Antonio", "Washington"}

dfc2 = pd.DataFrame()
for city in cityArr:
    dfct = dfc[dfc['Geography'].str.contains(city)]
    dfc2 = dfc2.append(dfct, ignore_index=False)
    
dfc2
# Out:
#                                                Geography  \
# Id2
# 41620                      Salt Lake City, UT Metro Area
# 40900  Sacramento--Roseville--Arden-Arcade, CA Metro ...
# 14460          Boston-Cambridge-Newton, MA-NH Metro Area
# 41700           San Antonio-New Braunfels, TX Metro Area
# 38900     Portland-Vancouver-Hillsboro, OR-WA Metro Area
# 38060             Phoenix-Mesa-Scottsdale, AZ Metro Area
# 36740           Orlando-Kissimmee-Sanford, FL Metro Area
# 19740              Denver-Aurora-Lakewood, CO Metro Area
# 16740       Charlotte-Concord-Gastonia, NC-SC Metro Area
# 35620   New York-Newark-Jersey City, NY-NJ-PA Metro Area
# 19100         Dallas-Fort Worth-Arlington, TX Metro Area
# 26420    Houston-The Woodlands-Sugar Land, TX Metro Area
# 35380                New Orleans-Metairie, LA Metro Area
# 31080      Los Angeles-Long Beach-Anaheim, CA Metro Area
# 47900  Washington-Arlington-Alexandria, DC-VA-MD-WV M...
# ...

# %%
import pandas as pd

# Setup Dataframe for all NBA data
# dfn = dataframe of all NBA data
dfn = pd.read_csv("~/GitHub/HomeFieldAdvantage/datasets/NBA.csv", encoding='latin-1', index_col=[1,0], skipinitialspace=True)
# Pare it down to just the Data for the Year 2010
# dfn10 = dataframe of just NBA teams in 2010
dfn10 = pd.read_csv("~/GitHub/HomeFieldAdvantage/datasets/NBA.csv", encoding='latin-1', index_col=[1,0], skipinitialspace=True)


dropYears =[1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 
           1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 
           1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 
           1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 
           1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999,
           2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009]

dfn10.drop(dropYears, level='Year', axis=0,inplace=True)
dfn10.head()
# Out:
#                           Wins  Loss  Home Wins  Home Loss  Away Wins  \
# Team                Year
# Atlanta Hawks       2010    44    38         24         17         20
# Boston Celtics      2010    56    26         33          8         23
# Charlotte Bobcats   2010    34    48         21         20         13
# Chicago Bulls       2010    62    20         36          5         26
# Cleveland Cavaliers 2010    19    63         12         29          7
#
#                           Away Loss   HomePCT   AwayPCT  TotalPCT
# Team                Year
# Atlanta Hawks       2010         21  0.585366  0.487805  0.536585
# Boston Celtics      2010         18  0.804878  0.560976  0.682927
# Charlotte Bobcats   2010         28  0.512195  0.317073  0.414634
# Chicago Bulls       2010         15  0.878049  0.634146  0.756098
# Cleveland Cavaliers 2010         34  0.292683  0.170732  0.231707

# %%
#Potentially helpful arrays for working with the dfn dataframe of all NBA data
yearArr = [1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 
           1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 
           1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 
           1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 
           1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999,
           2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010]

teamArr = ['Atlanta Hawks', 'Baltimore Bullets', 'Boston Celtics', 'Buffalo Braves', 'Capitol Bullets', 
         'Charlotte Bobcats', 'Charlotte Hornets', 'Chicago Bulls', 'Chicago Packers', 'Chicago Zephyrs', 
         'Cincinnati Royals', 'Cleveland Cavaliers', 'Dallas Mavericks', 'Denver Nuggets', 'Detroit Pistons', 
         'GoldenState Warriors', 'Houston Rockets', 'Indianapolis Olympians', 'Indiana Pacers', 'KansasCity-Omaha Kings', 
         'KansasCity Kings', 'LosAngeles Clippers', 'LosAngeles Lakers', 'Memphis Grizzlies', 'Miami Heat', 
         'Milwaukee Bucks', 'Milwaukee Hawks', 'Minneapolis Lakers', 'Minnesota Timberwolves', 'NewJersey Nets', 
         'NewOrleans Hornets', 'NewOrleans Jazz', 'NewYork Knicks', 'NewYork Nets', 'OklahomaCity Thunder', 'Orlando Magic', 
         'Philadelphia 76ers', 'Philadelphia Warriors', 'Phoenix Suns', 'Portland Trailblazers', 'Rochester Royals', 
         'Sacramento Kings', 'SanAntonio Spurs', 'SanDiego Clippers', 'SanDiego Rockets', 'SanFrancisco Warriors', 
         'Seattle Supersonics', 'St.Louis Hawks', 'Syracuse Nationals', 'Toronto Raptors', 'Tri-Cities Blackhawks', 
         'Utah Jazz', 'Vancouver Grizzlies', 'Washington Bullets', 'Washington Capitols', 'Washington Wizards']

# %%
import numpy as np # linear algebra
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
plt.plot(dfn.HomePCT + np.random.normal(0,0.01,len(dfn)),dfn.AwayPCT + np.random.normal(0,0.01,len(dfn)),'o', alpha = 0.4)
plt.plot([0,1],[0,1])
plt.xlabel('Home PCT')
plt.ylabel('Away PCT')
plt.title('Home vs Away PCT in the NBA')
# Out:
# Text(0.5,1,'Home vs Away PCT in the NBA')

# %%
dfn['Home_Factor'] = np.true_divide((dfn.HomePCT - dfn.AwayPCT),(dfn.HomePCT + dfn.AwayPCT))

import seaborn as sns
sns.kdeplot(dfn.Home_Factor, shade = True)
plt.xlim([-0.5,1.0])
plt.legend(['NBA'])
plt.plot([0,0],[0,3])
plt.xlabel('Home Factor')
# Out:
# Text(0.5,0,'Home Factor')

# %%
plt.plot(dfn.index.get_level_values(1) + np.random.normal(0,0.5,len(dfn)),dfn.Home_Factor,'o', alpha = 0.8)
x = dfn.index.get_level_values(1)
y = dfn.Home_Factor
fn = np.polyfit(x,y,1)
fit_fn = np.poly1d(fn) 
plt.plot(x,fit_fn(x))
plt.xlabel('Year')
plt.ylim([-1,1])
plt.xlim([1950,2010])
# Out:
# (1950, 2010)
